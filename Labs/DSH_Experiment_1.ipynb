# %% [markdown]
# **Importing Libraries.**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Data Cleaning**

# %% [markdown]
# Load the Patient Demographics Table.

# %%
patientDemographics =  pd.read_csv('/content/Patient Demographics.csv')
patientDemographics.set_index("Patient ID", inplace=True)

# %%
patientDemographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 1 to 10
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            10 non-null     object
#  1   Gender          10 non-null     object
#  2   Age             9 non-null      float64
#  3   Date of Birth   10 non-null     object
#  4   Address         10 non-null     object
#  5   Contact Number  9 non-null      object
#  6   Email           10 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 640.0+ bytes

# %%
patientDemographics.isnull().sum()
# Out:
# Name              0
# Gender            0
# Age               1
# Date of Birth     0
# Address           0
# Contact Number    1
# Email             0
# dtype: int64

# %% [markdown]
# Data Preprocessing - Fill missing age values.
#
# Data Validation - Age can't be negative.

# %%
import datetime
def calculateAge(dob):
  if datetime.date.fromisoformat(dob) > datetime.date.today():
    raise ValueError('Please check Date-of-Birth.')
  return datetime.date.today().year - datetime.date.fromisoformat(dob).year

# %%
patientDemographics['Age'] = patientDemographics['Date of Birth'].apply(calculateAge)

# %%
patientDemographics.head()
# Out:
#                        Name  Gender  Age Date of Birth       Address  \
# Patient ID
# 1                  John Doe    Male   45    1978-05-12   123 Main St
# 2                Jane Smith  Female   32    1991-09-28    456 Elm St
# 3           Michael Johnson    Male   58    1965-03-07   789 Oak Ave
# 4               Emily Davis  Female   43    1980-12-19   321 Pine St
# 5                Robert Lee    Male   67    1956-08-02  654 Birch Ln
#
#            Contact Number                       Email
# Patient ID
# 1                555-1234         johndoe@example.com
# 2                555-5678       janesmith@example.com
# 3                555-9876  michaeljohnson@example.com
# 4                555-2468      emilydavis@example.com
# 5                555-1357       robertlee@example.com

# %% [markdown]
# Data Cleaning for Other Tables.

# %%
Diagnoses = pd.read_csv('/content/Diagnoses.csv')
Diagnoses.set_index("Diagnosis ID", inplace=True)
Medication = pd.read_csv('/content/Medication.csv')
Medication.set_index("Medication ID", inplace=True)
labTests = pd.read_csv('/content/Laboratory Test Results.csv')
labTests.set_index("Lab Test ID", inplace=True)

# %%
Diagnoses.head()
# Out:
#               Patient ID Diagnosis Description Date of Diagnosis
# Diagnosis ID
# 101                    1       Type 2 Diabetes        2010-08-15
# 102                    1                   NaN        2012-03-22
# 103                    2            Depression        2015-11-10
# 104                    3                Asthma        2005-06-30
# 105                    3             Arthritis        2007-09-17

# %%
Medication.head()
# Out:
#                Patient ID    Medication Name Dosage   Frequency  Start Date  \
# Medication ID
# 201                     1          Metformin  500mg  Once daily  2010-08-15
# 202                     1         Lisinopril   10mg  Once daily  2012-03-22
# 203                     2                NaN   20mg  Once daily  2015-11-10
# 204                     3  Albuterol Inhaler    NaN   As needed  2005-06-30
# 205                     4        Sumatriptan  100mg   As needed  2018-04-05
#
#                  End Date
# Medication ID
# 201            2021-06-30
# 202            2023-01-31
# 203            2023-07-15
# 204            2022-12-31
# 205            2023-07-15

# %%
labTests.head()
# Out:
#              Patient ID               Lab Test Name Result Value  \
# Lab Test ID
# 301                   1         Fasting Blood Sugar          105
# 302                   1                         NaN          6.2
# 303                   2  CBC - Complete Blood Count          NaN
# 304                   3     Pulmonary Function Test           80
# 305                   4              Headache Diary            5
#
#               Result Unit Reference Range Date of Test
# Lab Test ID
# 301                 mg/dL          70-100   2010-08-15
# 302                     %         4.0-5.6   2012-03-22
# 303          Million/mm^3         4.2-5.8   2015-11-10
# 304                     %             >70   2005-06-30
# 305                   NaN             NaN   2018-04-05

# %%
print("Diagnoses")
Diagnoses.info()
print("")
print("Medication")
Medication.info()
print("")
print("Lab Tests")
labTests.info()
# Out:
# Diagnoses
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 101 to 116
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Patient ID             16 non-null     int64
#  1   Diagnosis Description  13 non-null     object
#  2   Date of Diagnosis      13 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 512.0+ bytes
#
# Medication
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 201 to 211
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Patient ID       11 non-null     int64
#  1   Medication Name  10 non-null     object
#  2   Dosage           9 non-null      object
#  3   Frequency        10 non-null     object
#  4   Start Date       11 non-null     object
#  5   End Date         9 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 616.0+ bytes
#
# Lab Tests
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 301 to 311
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Patient ID       11 non-null     int64
#  1   Lab Test Name    8 non-null      object
#  2   Result Value     9 non-null      object
#  3   Result Unit      10 non-null     object
#  4   Reference Range  10 non-null     object
#  5   Date of Test     11 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 616.0+ bytes

# %%
Diagnoses.isnull().sum()
# Out:
# Patient ID               0
# Diagnosis Description    3
# Date of Diagnosis        3
# dtype: int64

# %%
Medication.isnull().sum()
# Out:
# Patient ID         0
# Medication Name    1
# Dosage             2
# Frequency          1
# Start Date         0
# End Date           2
# dtype: int64

# %%
labTests.isnull().sum()
# Out:
# Patient ID         0
# Lab Test Name      3
# Result Value       2
# Result Unit        1
# Reference Range    1
# Date of Test       0
# dtype: int64

# %%
Diagnoses.dropna(inplace=True)
Medication.dropna(inplace=True)
labTests.dropna(inplace=True)

# %% [markdown]
# **Data Integration**

# %%
ptDemo = patientDemographics.drop(['Address', 'Date of Birth', 'Contact Number', 'Email'], axis=1)
ptDemoWithDoB = patientDemographics.drop(['Address', 'Contact Number', 'Email'], axis=1)

# %% [markdown]
# Data Merging

# %%
patientDiagnoses = pd.merge(ptDemo, Diagnoses, on='Patient ID', how='inner')
patientDiagnoses.head()
# Out:
#    Patient ID             Name  Gender  Age    Diagnosis Description  \
# 0           1         John Doe    Male   45          Type 2 Diabetes
# 1           2       Jane Smith  Female   32               Depression
# 2           3  Michael Johnson    Male   58                   Asthma
# 3           3  Michael Johnson    Male   58                Arthritis
# 4           5       Robert Lee    Male   67  Coronary Artery Disease
#
#   Date of Diagnosis
# 0        2010-08-15
# 1        2015-11-10
# 2        2005-06-30
# 3        2007-09-17
# 4        2011-10-12

# %%
patientMedication = pd.merge(ptDemo, Medication, on='Patient ID', how='inner')
patientMedication.head()
# Out:
#    Patient ID          Name  Gender  Age Medication Name Dosage   Frequency  \
# 0           1      John Doe    Male   45       Metformin  500mg  Once daily
# 1           1      John Doe    Male   45      Lisinopril   10mg  Once daily
# 2           4   Emily Davis  Female   43     Sumatriptan  100mg   As needed
# 3           5    Robert Lee    Male   67    Atorvastatin   40mg  Once daily
# 4           6  Susan Wilson  Female   54           Xanax  0.5mg   As needed
#
#    Start Date    End Date
# 0  2010-08-15  2021-06-30
# 1  2012-03-22  2023-01-31
# 2  2018-04-05  2023-07-15
# 3  2011-10-12  2023-07-15
# 4  2002-09-28  2023-07-15

# %%
patientLabTests = pd.merge(ptDemoWithDoB, labTests, on='Patient ID', how='inner')
patientLabTests.head()
# Out:
#    Patient ID             Name  Gender  Age Date of Birth  \
# 0           1         John Doe    Male   45    1978-05-12
# 1           3  Michael Johnson    Male   58    1965-03-07
# 2           5       Robert Lee    Male   67    1956-08-02
# 3           7   David Thompson    Male   35    1988-07-03
# 4          10       Amy Garcia  Female   61    1962-04-07
#
#              Lab Test Name Result Value Result Unit Reference Range  \
# 0      Fasting Blood Sugar          105       mg/dL          70-100
# 1  Pulmonary Function Test           80           %             >70
# 2        Cholesterol Panel          200       mg/dL            <200
# 3    Thyroid Function Test           T4      mcg/dL         0.8-1.8
# 4    Body Mass Index (BMI)           30      kg/m^2       18.5-24.9
#
#   Date of Test
# 0   2010-08-15
# 1   2005-06-30
# 2   2011-10-12
# 3   2019-02-11
# 4   2004-03-22

# %% [markdown]
# **Data Transformation**

# %% [markdown]
# Variable Transformation

# %%
Diagnoses['Date of Diagnosis'] = Diagnoses['Date of Diagnosis'].astype('datetime64[ns]')
Medication['Start Date'] = Medication['Start Date'].astype('datetime64[ns]')
Medication['End Date'] = Medication['End Date'].astype('datetime64[ns]')
labTests['Date of Test'] = labTests['Date of Test'].astype('datetime64[ns]')

# %% [markdown]
# Feature Engineering

# %%
patientLabTests['Age at Time of Test'] = (patientLabTests['Date of Test'].astype('datetime64[ns]')
                                        - patientLabTests['Date of Birth'].astype('datetime64[ns]'))
patientLabTests['Age at Time of Test'] = (patientLabTests['Age at Time of Test']/np.timedelta64(1, 'Y')).astype('int')
patientLabTests.drop(['Date of Birth'], axis=1)
# Out:
#    Patient ID             Name  Gender  Age            Lab Test Name  \
# 0           1         John Doe    Male   45      Fasting Blood Sugar
# 1           3  Michael Johnson    Male   58  Pulmonary Function Test
# 2           5       Robert Lee    Male   67        Cholesterol Panel
# 3           7   David Thompson    Male   35    Thyroid Function Test
# 4          10       Amy Garcia  Female   61    Body Mass Index (BMI)
#
#   Result Value Result Unit Reference Range Date of Test  Age at Time of Test
# 0          105       mg/dL          70-100   2010-08-15                   32
# 1           80           %             >70   2005-06-30                   40
# 2          200       mg/dL            <200   2011-10-12                   55
# 3           T4      mcg/dL         0.8-1.8   2019-02-11                   30
# 4           30      kg/m^2       18.5-24.9   2004-03-22                   41
